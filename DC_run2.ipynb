# %% [markdown]
# # DC for the warm Commissioning of 2x2 run2

# %%
# %load_ext autoreload

# %autoreload 2

from calibWvfms import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
d = '/Users/nsallin/develop/data/2x2/'
f = 'mpd_run_dbg_rctl_660.FLOW.hdf5'

wvfms = calibWvfms(filedir = d, filename = f, output_path='/Users/nsallin/develop/data/2x2/2x2_calib/DC')
# Out:
# Processing file /Users/nsallin/develop/data/2x2/mpd_run_dbg_rctl_660.FLOW.hdf5
# The output path is set to /Users/nsallin/develop/data/2x2/2x2_calib/DC
# Number of events in the selection: 5004

# %%
len(wvfms.light_wvfms[12][0,0])
print(wvfms.light_wvfms.shape)
# Out:
# (5004, 8, 64, 1000)

# %%
# wvfms.plot_wvfms(13, 0, 10, (500,600), -27600)

wvfms.plot_wvfm(13, 3, 10)

# %%
wvfms.plot_wvfm(13, 3, 10, peakFinder=True, minWidth=9, verbose=False, show_plot=True)

# %%
wvfms.plot_wvfms([7,8], peakFinder=True, minWidth=9, verbose=False, save_plots=True, show_plots=False)

# %%
inactive_channels = [0,1,2,3,16,17,18,19,32,33,34,35,48,49,50,51]

wvfms.plot_summaryDC(adcs=3, peakFinder_minWidth=9, show_plots=True, inactive_channels=inactive_channels)

# %%
# Out:
# 0
# 1
# 2
# 3
# 16
# 17
# 18
# 19
# 32
# 33
# 34
# 35
# 48
# 49
# 50
# 51
