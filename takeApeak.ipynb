# %%
import h5py
import numpy as np
import os

file_path = "/global/cfs/cdirs/dune/users/ajwhite/2x2_Data/2x2_Sums"
file_name = "mpd_run_dbg_rctl_832.FLOW.hdf5"

f = h5py.File(os.path.join(file_path, file_name), 'r')

light_wvfms = f['light/wvfm/data']['samples']
